# %% [markdown]
# # The Three Body Problem
# Using Verlet intergration evolve a 3 body system for position and velocity.
# Calculate angular momentum of the bodies.
# Calculate total energy (potential and kinetic).
# ### Verlet
# velocity half step
# $ v_{n+\frac{1}{2}} = v_n +\frac{1}{2} ha (x_n) $
# $ x_{n+1} = x_n +hv_{n+\frac{1}{2}} $
# $ v_{n+1} = v_{n+\frac{1}{2}} +\frac{1}{2} ha (x_{n+1}) $
#
# $ h $ is timestep
# $ a(x) $ is acceleration at point x. I will calulate using the force function defined near the top, and divide it by mass. So that it in keeping with the other solvers here.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.constants as sc
from cycler import cycler
import pandas as pd

# %%
def Data_save(p, v, E, L, t, f_name):
    """Function for saving positions, velocity, energy and angular momentum produced to a txt file.
    IN:
        p: An array holding all of the positions of that timestep. Cartesain
        v: An array holding all the velocities of that timestep. Cartesain
        E: Total energy of the system
        L: Total angular momentum of the system
        t: Time of the particular step
        f_name: The file the data is being saved to."""
    f = open(f_name, "a")
    f.write("\n" + f"{p[0,0]}" + "\t" + f"{p[0,1]}" + "\t" + f"{p[1,0]}" + "\t" + f"{p[1,1]}")
    f.write("\t" + f"{v[0,0]}" + "\t" + f"{v[0,1]}" + "\t" + f"{v[1,0]}" + "\t" + f"{v[1,1]}")
    f.write("\t" + f"{E}" + "\t" + f"{L}" + "\t" +f"{t}")
    f.close()

# %%
def Grav_eng(pos_e, ma_e, pos_other, ma_other, ep, G):
    """Grav_eng(pos_e, ma_e, pos_other, ma_other):
    Calculates tthe gravtiational energy between two bodies.
    U = -GMm/(r+ep)
    IN:
        pos_e: position of the planet in question. [x,y]
        ma_e: mas of the planet in question.
        pos_other: position of the other planet. [x,y]
        ma_other: mas of the other planet.
        ep: extra bit to make sure the numbers dont blow up to much at low distances.
        G: GRavitational constant.
    OUT:
        g_e: gravitational potential energy."""
    
    dif = pos_other-pos_e
    g_e = (-G * ma_e *ma_other) / (np.linalg.norm(dif+ep))

    return g_e

# %%
def Kin_eng(vel_e, m_e):
    """Kin_eng(vel_e, m_e):
    Calculate the kinetic energy.
    E = 0.5mv^2
    IN:
        vel_e: velocity of a body. [vx,vy]
        m_e: mass of the planet in question.
    OUT:
        k_e: Kinetic energy of the body."""
    
    k_e = 0.5*m_e*vel_e**2
    k_e = np.linalg.norm(k_e)

    return k_e

# %%
def Angular_momentum():
    """A function which calculates the angular momentum of the system.
    IN:
    OUT:"""

# %%
def Acceleration( pos_a, ma_a, pos_other, ep, G):
    """Acceleration( pos_a, ma_a, pos_other, ma_other, ep, G):
    A function for calculating the gravitational acceleration between two bodies.
    g = GM/r^2
    IN:
        pos_a: position of the planet in question. [x,y]
        ma_a: An array of all of the planetary masses.
        pos_other: position of the other body. [x,y]
        ep: extra bit to make sure the numbers dont blow up to much at low distances.
        G: Gravitational constant.
    OUT:
        g_e: gravitational potential energy"""
    
    x_acc = np.array([])
    y_acc = np.array([])

    #print(f"len(ma) {len(ma)},, ma {ma}")
    for g in range(len(ma_a)):
        print(f"g {g}")
        #print(f" pos_other[g] { pos_other[g]}")
        #print(f" pos_a { pos_a}")
        print(f" (pos_other[g,0]/pos_a[0]): {np.round(pos_other[g,0]/pos_a[0],6)}")
        print(f" (pos_other[g,1]/pos_a[1]): {np.round(pos_other[g,1]/pos_a[1],6)}")
        if np.round(pos_other[g,0]/pos_a[0],6) and np.round(pos_other[g,1]/pos_a[1],6)  == 1:
            print("snap")
            continue
            
        else:

            dif = pos_a - pos_other[g]               #CHANGE: Calculated dif in one go (didnt split x,y components). Also swapped their order in subtraction.
            print(f"dif {dif}")
            
            acc_temp = (-G*ma_a[g]*dif)/ (np.linalg.norm(dif + ep)**3)            #CHANGE: Changed mass on numerator, and input of np.linalg.norm

            print(f"acc_temp {acc_temp}")
    
            x_acc = np.append(x_acc, acc_temp[0])
            y_acc = np.append(y_acc, acc_temp[1])
            

    
    acc = np.array([np.sum(x_acc),np.sum(y_acc)])

    print(f"sum acc {acc}")
    return acc

# %%
def Verlet(pos_v, vel_v, ma, ep, G, t_s):
    """A function that runs a single loop of a verlet intergrator.
    IN:
        pos_v: an array holding the positions of al the planets at the beginning of a tine step.
        vel_v: an array holding the velocities at the begining of a time step.
        ma: an array holding the mass of all of the planets.
        ep: extra bit to make sure the numbers dont blow up to much at low distances.
        G: gravitational constant.
        t_s: time step.

    OUT:
        pos_full: an array holding the position of all the bodies at the end of a time step
        vel_full: an array holding the velocities of all the bodies at the end of a time step
        """

    pos_full = np.array([])
    vel_full = np.array([])

    for v in range(len(ma)):
        a_half = Acceleration(pos_a = pos_v[v], ma_a = ma, pos_other = pos_v, ep = ep, G = G)     #acceleration fro half step
    
        v_half = vel_v[v] + (0.5 * t_s * a_half)                                                          #Caclcualting the halfstep velocities for a planet

        p_full = pos_v[v] + (t_s * v_half)     #Caclcualting the fullstep positions for a planet

        if pos_full.shape ==(0,):
            pos_full = np.array([p_full])
        else:
            pos_full = np.vstack((pos_full, np.array([p_full])))
        #print(f"v {v}")
    print(f"a_half {a_half}")

    acc_array = np.array([[0,0]])
    for ve in range(len(ma)):
        #print(f"pos_full[ve] {pos_full[ve]}")
        a_full = Acceleration(pos_a = pos_full[ve], ma_a = ma, pos_other = pos_full, ep = ep, G = G)     #accelreation for full step
        print(f"a_full {a_full}")
        v_full = v_half + (0.5 * t_s * a_full)     #Caclcualting the fullstep velocities for a planet
        
        if vel_full.shape ==(0,):
            vel_full = np.array([v_full])
        else:
            vel_full= np.vstack((vel_full, np.array([v_full])))
        #print(f"ve {ve}")
        acc_array = np.vstack((acc_array,a_full))
        
        #print(f"ve {ve}")
    print(f"acc_array {acc_array}")    
    return pos_full, vel_full

# %% [markdown]
# ### Importing data and setting initial conditions
# Initial conditions are stored in a data file

# %%
data = pd.read_csv("3_body_input_and_tests.txt",delim_whitespace=True)
data
# Out:
# C:\Users\bs583\AppData\Local\Temp\ipykernel_17296\2616778796.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv("3_body_input_and_tests.txt",delim_whitespace=True)
#       name  pos1x  pos1y  pos2x  pos2y  pos3x  pos3y   vel1x   vel1y   vel2x  \
# 0    Test1      0      0      1      0      0  0.000  0.0000  0.0000  0.0000
# 1    Test2      1      1     -1     -1      0  0.000  0.0000  0.0000  0.0000
# 2    Test3      1      0     -1      0      0  0.000  0.0000  5.0000  0.0000
# 3    Test4      1      3      2      2      0  0.000  3.0000  2.0000  1.0000
# 4    Test5      1      1     -1     -2      3 -2.000  1.0000  1.0000  2.0000
# 5    Test6      0      0      2      0      1  1.732  0.0000  0.0000  0.0000
# 6    Test7      1      1     -2      1      4  1.000  0.0000  0.0000  0.0000
# 7    Test8      1      1     -2      1      4  1.000  1.0000 -0.5000  0.0000
# 8   FigOf8     -1      0      1      0      0  0.000  0.3471  0.5327  0.3471
# 9    Bfly1     -1      0      1      0      0  0.000  0.3068  0.1255  0.3068
# 10   Moth1     -1      0      1      0      0  0.000  0.4644  0.3960  0.4644
# 11   Bfly4     -1      0      1      0      0  0.000  0.3501  0.0793  0.3501
#
#       vel2y   vel3x   vel3y    m1    m2  m3
# 0   10.0000  0.0000  0.0000   100     1   0
# 1    0.0000  0.0000  0.0000  1000  1000   0
# 2   -5.0000  0.0000  0.0000    10    10   0
# 3    2.0000  0.0000  0.0000     2     2   0
# 4    2.0000 -1.0000 -2.0000     1     1   1
# 5    0.0000  0.0000  0.0000     5     5   5
# 6    5.0000  0.0000 -5.0000   100     5   5
# 7    5.0000  0.0000 -5.0000   100     5   5
# 8    0.5327 -0.6942 -1.0654     1     1   1
# 9    0.1255 -0.6136  0.2510     1     1   1
# 10   0.3960  0.9288  0.7920     1     1   1
# 11   0.0793 -0.7002 -0.1586     1     1   1

# %%
initial = 8
in_con = data.iloc[initial]

masses = np.array([in_con.loc["m1"], in_con.loc["m2"], in_con.loc["m3"]])
i_positions = np.array([[in_con.loc["pos1x"],in_con.loc["pos1y"]], [in_con.loc["pos2x"],in_con.loc["pos2y"]], [in_con.loc["pos3x"],in_con.loc["pos3y"]]])
i_velocities = np.array([[in_con.loc["vel1x"],in_con.loc["vel1y"]], [in_con.loc["vel2x"],in_con.loc["vel2y"]], [in_con.loc["vel3x"],in_con.loc["vel3y"]]])

for i in range(len(masses)):
    if masses[i] == 0:
        masses = np.delete(masses, i)
        i_positions = np.delete(i_positions, i, 0)
        i_velocities = np.delete(i_velocities, i, 0)


i_positions
# Out:
# array([[-1.,  0.],
#        [ 1.,  0.],
#        [ 0.,  0.]])

# %%
fin = 5
time_step = 0.01
no_steps = int(fin/time_step)
epsilon = 0.1
G = 1
no_steps
# Out:
# 500

# %%
file_name = f"produced_data_system_{initial}.txt"
file = open(file_name, "w")

for a in range(len(masses)):
    #file.write("px1" + "\t" + "p1y" + "\t" + "p2x" + "\t" + "p2y" + "\t" + "p3x" + "\t" + "p3y" + "\t" + "vx1" + "\t" + "v1y" + "\t" + "v2x" + "\t" + "v2y" + "\t" + "v3x" + "\t" + "v3y" + "\t" + "Energy" + "\t" + "ang_mom")
    file.write(f"p{a+1}x" + "\t" + f"p{a+1}y" + "\t")
    
for a in range(len(masses)):
    file.write(f"v{a+1}x" + "\t" + f"v{a+1}y" + "\t")

file.write("Energy" + "\t" + "Ang_mom" + "\t" + "time")
    
file.close()

# %% [markdown]
# ### running everything

# %%
help(Verlet)
# Out:
# Help on function Verlet in module __main__:
#
# Verlet(pos_v, vel_v, ma, ep, G, t_s)
#     A function that runs a single loop of a verlet intergrator.
#     IN:
#         pos_v: an array holding the positions of al the planets at the beginning of a tine step.
#         vel_v: an array holding the velocities at the begining of a time step.
#         ma: an array holding the mass of all of the planets.
#         ep: extra bit to make sure the numbers dont blow up to much at low distances.
#         G: gravitational constant.
#         t_s: time step.
#
#     OUT:
#         pos_full: an array holding the position of all the bodies at the end of a time step
#         vel_full: an array holding the velocities of all the bodies at the end of a time step

# %%
print(i_velocities)
# Out:
# [[ 0.3471  0.5327]
#  [ 0.3471  0.5327]
#  [-0.6942 -1.0654]]

# %%
pos = i_positions
vel = i_velocities
fig =  plt.figure()
ax = fig.add_subplot()
for i in range(no_steps):
    print(f"pos {pos[0]}")
    ax.scatter(pos[0,0], pos[0,1], color = "k")
    ax.scatter(pos[1,0] ,pos[1,1], color = "red")
    ax.scatter(pos[2,0] ,pos[2,1], color = "blue")
    time = i *time_step
    Data_save(p=pos, v=vel, E=0, L=0, t=time, f_name = file_name)
    new_pos, new_vel = Verlet(pos_v=pos, vel_v=vel, ma=masses, ep=epsilon, G=G, t_s=time_step)     #Calling verlet intergrator

    
    #print(new_pos)
    print(f"vel-new_vel {vel-new_vel}")
    pos = new_pos
    vel = new_vel

ax.grid(True)
# Out:
# pos [-1.  0.]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): nan
# dif [0. 0.]
# acc_temp [-0. -0.]
# g 1
#  (pos_other[g,0]/pos_a[0]): -1.0
#  (pos_other[g,1]/pos_a[1]): nan
# dif [-2.  0.]
# acc_temp [ 0.29038029 -0.        ]
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.0
#  (pos_other[g,1]/pos_a[1]): nan
# dif [-1.  0.]
# acc_temp [ 1.34672593 -0.        ]
# sum acc [1.63710622 0.        ]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.0
#  (pos_other[g,1]/pos_a[1]): nan
# dif [2. 0.]
# acc_temp [-0.21522692 -0.        ]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): nan
# dif [0. 0.]
# acc_temp [-0. -0.]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.0
#  (pos_other[g,1]/pos_a[1]): nan
# dif [1. 0.]
# acc_temp [-0.74209628 -0.        ]
# sum acc [-0.9573232  0.       ]
# g 0
#  (pos_other[g,0]/pos_a[0]): -inf
#  (pos_other[g,1]/pos_a[1]): nan
# dif [1. 0.]
# acc_temp [-0.74209628 -0.        ]
# g 1
#  (pos_other[g,0]/pos_a[0]): inf
#  (pos_other[g,1]/pos_a[1]): nan
# dif [-1.  0.]
# acc_temp [ 1.34672593 -0.        ]
# g 2
#  (pos_other[g,0]/pos_a[0]): nan
#  (pos_other[g,1]/pos_a[1]): nan
# dif [0. 0.]
# acc_temp [-0. -0.]
# sum acc [0.60462965 0.        ]
# a_half [0.60462965 0.        ]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -1.007001
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.006936
#  (pos_other[g,1]/pos_a[1]): -2.0
# dif [-0.98953538  0.015981  ]
# acc_temp [ 1.37075634 -0.02213772]
# sum acc [ 1.37075634 -0.02213772]
# a_full [ 1.37075634 -0.02213772]
# g 0
#  (pos_other[g,0]/pos_a[0]): -0.993048
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.006888
#  (pos_other[g,1]/pos_a[1]): -2.0
# dif [1.0103349 0.015981 ]
# acc_temp [-0.72616277 -0.0114861 ]
# sum acc [-0.72616277 -0.0114861 ]
# a_full [-0.72616277 -0.0114861 ]
# g 0
#  (pos_other[g,0]/pos_a[0]): 144.166741
#  (pos_other[g,1]/pos_a[1]): -0.5
# dif [ 0.98953538 -0.015981  ]
# acc_temp [-0.7583067   0.01224666]
# g 1
#  (pos_other[g,0]/pos_a[0]): -145.176033
#  (pos_other[g,1]/pos_a[1]): -0.5
# dif [-1.0103349 -0.015981 ]
# acc_temp [1.32231859 0.02091581]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56401189 0.03316247]
# a_full [0.56401189 0.03316247]
# acc_array [[ 0.          0.        ]
#  [ 1.37075634 -0.02213772]
#  [-0.72616277 -0.0114861 ]
#  [ 0.56401189  0.03316247]]
# vel-new_vel [[ 1.03142307e+00  1.59821069e+00]
#  [ 1.04190767e+00  1.59815743e+00]
#  [-5.84320768e-03 -1.65812333e-04]]
# pos [-0.99644714  0.005327  ]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -1.007001
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.006936
#  (pos_other[g,1]/pos_a[1]): -2.0
# dif [-0.98953538  0.015981  ]
# acc_temp [ 1.37075634 -0.02213772]
# sum acc [ 1.37075634 -0.02213772]
# g 0
#  (pos_other[g,0]/pos_a[0]): -0.993048
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.006888
#  (pos_other[g,1]/pos_a[1]): -2.0
# dif [1.0103349 0.015981 ]
# acc_temp [-0.72616277 -0.0114861 ]
# sum acc [-0.72616277 -0.0114861 ]
# g 0
#  (pos_other[g,0]/pos_a[0]): 144.166741
#  (pos_other[g,1]/pos_a[1]): -0.5
# dif [ 0.98953538 -0.015981  ]
# acc_temp [-0.7583067   0.01224666]
# g 1
#  (pos_other[g,0]/pos_a[0]): -145.176033
#  (pos_other[g,1]/pos_a[1]): -0.5
# dif [-1.0103349 -0.015981 ]
# acc_temp [1.32231859 0.02091581]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56401189 0.03316247]
# a_half [0.56401189 0.03316247]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.993239
#  (pos_other[g,1]/pos_a[1]): 0.9998
# dif [-1.99966059e+00 -1.06516205e-06]
# acc_temp [2.90486258e-01 1.54733729e-07]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.013723
#  (pos_other[g,1]/pos_a[1]): 3.997716
# dif [-0.9894547   0.01597547]
# acc_temp [ 1.37101462 -0.02213603]
# sum acc [ 1.66150088 -0.02213588]
# a_full [ 1.66150088 -0.02213588]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.006807
#  (pos_other[g,1]/pos_a[1]): 1.0002
# dif [1.99966059e+00 1.06516205e-06]
# acc_temp [-2.15294518e-01 -1.14681237e-07]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.013816
#  (pos_other[g,1]/pos_a[1]): 3.998515
# dif [1.01020588 0.01597654]
# acc_temp [-0.72632137 -0.01148687]
# sum acc [-0.94161589 -0.01148698]
# a_full [-0.94161589 -0.01148698]
# g 0
#  (pos_other[g,0]/pos_a[0]): 72.870773
#  (pos_other[g,1]/pos_a[1]): 0.250143
# dif [ 0.9894547  -0.01597547]
# acc_temp [-0.75841146  0.01224511]
# g 1
#  (pos_other[g,0]/pos_a[0]): -72.378072
#  (pos_other[g,1]/pos_a[1]): 0.250093
# dif [-1.01020588 -0.01597654]
# acc_temp [1.32270551 0.02091876]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56429405 0.03316386]
# a_full [0.56429405 0.03316386]
# acc_array [[ 0.          0.        ]
#  [ 1.66150088 -0.02213588]
#  [-0.94161589 -0.01148698]
#  [ 0.56429405  0.03316386]]
# vel-new_vel [[-0.00709384 -0.00033163]
#  [-0.00456285 -0.00033162]
#  [-0.00564153 -0.00033163]]
# pos [-1.00322184 -0.00532921]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.993239
#  (pos_other[g,1]/pos_a[1]): 0.9998
# dif [-1.99966059e+00 -1.06516205e-06]
# acc_temp [2.90486258e-01 1.54733729e-07]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.013723
#  (pos_other[g,1]/pos_a[1]): 3.997716
# dif [-0.9894547   0.01597547]
# acc_temp [ 1.37101462 -0.02213603]
# sum acc [ 1.66150088 -0.02213588]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.006807
#  (pos_other[g,1]/pos_a[1]): 1.0002
# dif [1.99966059e+00 1.06516205e-06]
# acc_temp [-2.15294518e-01 -1.14681237e-07]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.013816
#  (pos_other[g,1]/pos_a[1]): 3.998515
# dif [1.01020588 0.01597654]
# acc_temp [-0.72632137 -0.01148687]
# sum acc [-0.94161589 -0.01148698]
# g 0
#  (pos_other[g,0]/pos_a[0]): 72.870773
#  (pos_other[g,1]/pos_a[1]): 0.250143
# dif [ 0.9894547  -0.01597547]
# acc_temp [-0.75841146  0.01224511]
# g 1
#  (pos_other[g,0]/pos_a[0]): -72.378072
#  (pos_other[g,1]/pos_a[1]): 0.250093
# dif [-1.01020588 -0.01597654]
# acc_temp [1.32270551 0.02091876]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56429405 0.03316386]
# a_half [0.56429405 0.03316386]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.979779
#  (pos_other[g,1]/pos_a[1]): 0.999867
# dif [-1.99940027e+00 -2.13005198e-06]
# acc_temp [2.90567572e-01 3.09554841e-07]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.020364
#  (pos_other[g,1]/pos_a[1]): 1.999238
# dif [-0.98934498  0.01596994]
# acc_temp [ 1.37136483 -0.02213648]
# sum acc [ 1.6619324  -0.02213617]
# a_full [ 1.6619324  -0.02213617]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.020639
#  (pos_other[g,1]/pos_a[1]): 1.000133
# dif [1.99940027e+00 2.13005198e-06]
# acc_temp [-2.15346379e-01 -2.29418285e-07]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.020785
#  (pos_other[g,1]/pos_a[1]): 1.999505
# dif [1.01005529 0.01597207]
# acc_temp [-0.72650641 -0.01148829]
# sum acc [-0.94185279 -0.01148852]
# a_full [-0.94185279 -0.01148852]
# g 0
#  (pos_other[g,0]/pos_a[0]): 49.105681
#  (pos_other[g,1]/pos_a[1]): 0.50019
# dif [ 0.98934498 -0.01596994]
# acc_temp [-0.75855428  0.01224453]
# g 1
#  (pos_other[g,0]/pos_a[0]): -48.112694
#  (pos_other[g,1]/pos_a[1]): 0.500124
# dif [-1.01005529 -0.01597207]
# acc_temp [1.32315763 0.02092318]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56460335 0.03316771]
# a_full [0.56460335 0.03316771]
# acc_array [[ 0.          0.        ]
#  [ 1.6619324  -0.02213617]
#  [-0.94185279 -0.01148852]
#  [ 0.56460335  0.03316771]]
# vel-new_vel [[-0.0056451  -0.00033164]
#  [-0.00564176 -0.00033163]
#  [-0.00564449 -0.00033166]]
# pos [-1.00991105 -0.01598211]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.979779
#  (pos_other[g,1]/pos_a[1]): 0.999867
# dif [-1.99940027e+00 -2.13005198e-06]
# acc_temp [2.90567572e-01 3.09554841e-07]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.020364
#  (pos_other[g,1]/pos_a[1]): 1.999238
# dif [-0.98934498  0.01596994]
# acc_temp [ 1.37136483 -0.02213648]
# sum acc [ 1.6619324  -0.02213617]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.020639
#  (pos_other[g,1]/pos_a[1]): 1.000133
# dif [1.99940027e+00 2.13005198e-06]
# acc_temp [-2.15346379e-01 -2.29418285e-07]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.020785
#  (pos_other[g,1]/pos_a[1]): 1.999505
# dif [1.01005529 0.01597207]
# acc_temp [-0.72650641 -0.01148829]
# sum acc [-0.94185279 -0.01148852]
# g 0
#  (pos_other[g,0]/pos_a[0]): 49.105681
#  (pos_other[g,1]/pos_a[1]): 0.50019
# dif [ 0.98934498 -0.01596994]
# acc_temp [-0.75855428  0.01224453]
# g 1
#  (pos_other[g,0]/pos_a[0]): -48.112694
#  (pos_other[g,1]/pos_a[1]): 0.500124
# dif [-1.01005529 -0.01597207]
# acc_temp [1.32315763 0.02092318]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56460335 0.03316771]
# a_half [0.56460335 0.03316771]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.966605
#  (pos_other[g,1]/pos_a[1]): 0.99988
# dif [-1.99913990e+00 -3.19481664e-06]
# acc_temp [2.90648942e-01 4.64484790e-07]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.026864
#  (pos_other[g,1]/pos_a[1]): 1.599452
# dif [-0.98923525  0.01596441]
# acc_temp [ 1.37171521 -0.02213692]
# sum acc [ 1.66236415 -0.02213646]
# a_full [ 1.66236415 -0.02213646]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.034549
#  (pos_other[g,1]/pos_a[1]): 1.00012
# dif [1.99913990e+00 3.19481664e-06]
# acc_temp [-2.15398272e-01 -3.44227027e-07]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.027792
#  (pos_other[g,1]/pos_a[1]): 1.599643
# dif [1.00990465 0.0159676 ]
# acc_temp [-0.72669159 -0.01148972]
# sum acc [-0.94208986 -0.01149007]
# a_full [-0.94208986 -0.01149007]
# g 0
#  (pos_other[g,0]/pos_a[0]): 37.224377
#  (pos_other[g,1]/pos_a[1]): 0.625214
# dif [ 0.98923525 -0.01596441]
# acc_temp [-0.75869715  0.01224396]
# g 1
#  (pos_other[g,0]/pos_a[0]): -35.98126
#  (pos_other[g,1]/pos_a[1]): 0.625139
# dif [-1.00990465 -0.0159676 ]
# acc_temp [1.32361015 0.0209276 ]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56491299 0.03317156]
# a_full [0.56491299 0.03317156]
# acc_array [[ 0.          0.        ]
#  [ 1.66236415 -0.02213646]
#  [-0.94208986 -0.01149007]
#  [ 0.56491299  0.03317156]]
# vel-new_vel [[-0.00564819 -0.00033168]
#  [-0.00564485 -0.00033167]
#  [-0.00564758 -0.0003317 ]]
# pos [-1.0165438  -0.02663169]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.966605
#  (pos_other[g,1]/pos_a[1]): 0.99988
# dif [-1.99913990e+00 -3.19481664e-06]
# acc_temp [2.90648942e-01 4.64484790e-07]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.026864
#  (pos_other[g,1]/pos_a[1]): 1.599452
# dif [-0.98923525  0.01596441]
# acc_temp [ 1.37171521 -0.02213692]
# sum acc [ 1.66236415 -0.02213646]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.034549
#  (pos_other[g,1]/pos_a[1]): 1.00012
# dif [1.99913990e+00 3.19481664e-06]
# acc_temp [-2.15398272e-01 -3.44227027e-07]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.027792
#  (pos_other[g,1]/pos_a[1]): 1.599643
# dif [1.00990465 0.0159676 ]
# acc_temp [-0.72669159 -0.01148972]
# sum acc [-0.94208986 -0.01149007]
# g 0
#  (pos_other[g,0]/pos_a[0]): 37.224377
#  (pos_other[g,1]/pos_a[1]): 0.625214
# dif [ 0.98923525 -0.01596441]
# acc_temp [-0.75869715  0.01224396]
# g 1
#  (pos_other[g,0]/pos_a[0]): -35.98126
#  (pos_other[g,1]/pos_a[1]): 0.625139
# dif [-1.00990465 -0.0159676 ]
# acc_temp [1.32361015 0.0209276 ]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56491299 0.03317156]
# a_half [0.56491299 0.03317156]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.95371
#  (pos_other[g,1]/pos_a[1]): 0.999886
# dif [-1.99887945e+00 -4.25945574e-06]
# acc_temp [2.90730366e-01 6.19523667e-07]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.033226
#  (pos_other[g,1]/pos_a[1]): 1.428105
# dif [-0.9891255   0.01595888]
# acc_temp [ 1.37206576 -0.02213736]
# sum acc [ 1.66279612 -0.02213674]
# a_full [ 1.66279612 -0.02213674]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.048537
#  (pos_other[g,1]/pos_a[1]): 1.000114
# dif [1.99887945e+00 4.25945574e-06]
# acc_temp [-2.15450198e-01 -4.59107517e-07]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.034839
#  (pos_other[g,1]/pos_a[1]): 1.428268
# dif [1.00975395 0.01596314]
# acc_temp [-0.7268769  -0.01149115]
# sum acc [-0.9423271  -0.01149161]
# a_full [-0.9423271  -0.01149161]
# g 0
#  (pos_other[g,0]/pos_a[0]): 30.096601
#  (pos_other[g,1]/pos_a[1]): 0.700229
# dif [ 0.9891255  -0.01595888]
# acc_temp [-0.75884009  0.01224338]
# g 1
#  (pos_other[g,0]/pos_a[0]): -28.703418
#  (pos_other[g,1]/pos_a[1]): 0.700149
# dif [-1.00975395 -0.01596314]
# acc_temp [1.32406306 0.02093203]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56522297 0.03317541]
# a_full [0.56522297 0.03317541]
# acc_array [[ 0.          0.        ]
#  [ 1.66279612 -0.02213674]
#  [-0.9423271  -0.01149161]
#  [ 0.56522297  0.03317541]]
# vel-new_vel [[-0.00565129 -0.00033171]
#  [-0.00564794 -0.00033171]
#  [-0.00565068 -0.00033173]]
# pos [-1.02312004 -0.03727796]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.95371
#  (pos_other[g,1]/pos_a[1]): 0.999886
# dif [-1.99887945e+00 -4.25945574e-06]
# acc_temp [2.90730366e-01 6.19523667e-07]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.033226
#  (pos_other[g,1]/pos_a[1]): 1.428105
# dif [-0.9891255   0.01595888]
# acc_temp [ 1.37206576 -0.02213736]
# sum acc [ 1.66279612 -0.02213674]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.048537
#  (pos_other[g,1]/pos_a[1]): 1.000114
# dif [1.99887945e+00 4.25945574e-06]
# acc_temp [-2.15450198e-01 -4.59107517e-07]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.034839
#  (pos_other[g,1]/pos_a[1]): 1.428268
# dif [1.00975395 0.01596314]
# acc_temp [-0.7268769  -0.01149115]
# sum acc [-0.9423271  -0.01149161]
# g 0
#  (pos_other[g,0]/pos_a[0]): 30.096601
#  (pos_other[g,1]/pos_a[1]): 0.700229
# dif [ 0.9891255  -0.01595888]
# acc_temp [-0.75884009  0.01224338]
# g 1
#  (pos_other[g,0]/pos_a[0]): -28.703418
#  (pos_other[g,1]/pos_a[1]): 0.700149
# dif [-1.00975395 -0.01596314]
# acc_temp [1.32406306 0.02093203]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56522297 0.03317541]
# a_half [0.56522297 0.03317541]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.941086
#  (pos_other[g,1]/pos_a[1]): 0.999889
# dif [-1.99861894e+00 -5.32396903e-06]
# acc_temp [2.90811846e-01 7.74671564e-07]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.039455
#  (pos_other[g,1]/pos_a[1]): 1.33291
# dif [-0.98901575  0.01595335]
# acc_temp [ 1.37241648 -0.0221378 ]
# sum acc [ 1.66322832 -0.02213703]
# a_full [ 1.66322832 -0.02213703]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.062603
#  (pos_other[g,1]/pos_a[1]): 1.000111
# dif [1.99861894e+00 5.32396903e-06]
# acc_temp [-2.15502155e-01 -5.74059806e-07]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.041925
#  (pos_other[g,1]/pos_a[1]): 1.333058
# dif [1.00960319 0.01595867]
# acc_temp [-0.72706235 -0.01149258]
# sum acc [-0.9425645  -0.01149316]
# a_full [-0.9425645  -0.01149316]
# g 0
#  (pos_other[g,0]/pos_a[0]): 25.345601
#  (pos_other[g,1]/pos_a[1]): 0.750238
# dif [ 0.98901575 -0.01595335]
# acc_temp [-0.75898308  0.0122428 ]
# g 1
#  (pos_other[g,0]/pos_a[0]): -23.852382
#  (pos_other[g,1]/pos_a[1]): 0.750155
# dif [-1.00960319 -0.01595867]
# acc_temp [1.32451637 0.02093646]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56553329 0.03317926]
# a_full [0.56553329 0.03317926]
# acc_array [[ 0.          0.        ]
#  [ 1.66322832 -0.02213703]
#  [-0.9425645  -0.01149316]
#  [ 0.56553329  0.03317926]]
# vel-new_vel [[-0.00565439 -0.00033175]
#  [-0.00565104 -0.00033175]
#  [-0.00565378 -0.00033177]]
# pos [-1.02963975 -0.0479209 ]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.941086
#  (pos_other[g,1]/pos_a[1]): 0.999889
# dif [-1.99861894e+00 -5.32396903e-06]
# acc_temp [2.90811846e-01 7.74671564e-07]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.039455
#  (pos_other[g,1]/pos_a[1]): 1.33291
# dif [-0.98901575  0.01595335]
# acc_temp [ 1.37241648 -0.0221378 ]
# sum acc [ 1.66322832 -0.02213703]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.062603
#  (pos_other[g,1]/pos_a[1]): 1.000111
# dif [1.99861894e+00 5.32396903e-06]
# acc_temp [-2.15502155e-01 -5.74059806e-07]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.041925
#  (pos_other[g,1]/pos_a[1]): 1.333058
# dif [1.00960319 0.01595867]
# acc_temp [-0.72706235 -0.01149258]
# sum acc [-0.9425645  -0.01149316]
# g 0
#  (pos_other[g,0]/pos_a[0]): 25.345601
#  (pos_other[g,1]/pos_a[1]): 0.750238
# dif [ 0.98901575 -0.01595335]
# acc_temp [-0.75898308  0.0122428 ]
# g 1
#  (pos_other[g,0]/pos_a[0]): -23.852382
#  (pos_other[g,1]/pos_a[1]): 0.750155
# dif [-1.00960319 -0.01595867]
# acc_temp [1.32451637 0.02093646]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56553329 0.03317926]
# a_half [0.56553329 0.03317926]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.928726
#  (pos_other[g,1]/pos_a[1]): 0.999891
# dif [-1.99835836e+00 -6.38835623e-06]
# acc_temp [2.90893380e-01 9.29928572e-07]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.045552
#  (pos_other[g,1]/pos_a[1]): 1.27233
# dif [-0.98890598  0.01594782]
# acc_temp [ 1.37276737 -0.02213824]
# sum acc [ 1.66366075 -0.02213731]
# a_full [ 1.66366075 -0.02213731]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.076744
#  (pos_other[g,1]/pos_a[1]): 1.000109
# dif [1.99835836e+00 6.38835623e-06]
# acc_temp [-2.15554145e-01 -6.89083945e-07]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.049048
#  (pos_other[g,1]/pos_a[1]): 1.272469
# dif [1.00945238 0.0159542 ]
# acc_temp [-0.72724793 -0.01149402]
# sum acc [-0.94280208 -0.01149471]
# a_full [-0.94280208 -0.01149471]
# g 0
#  (pos_other[g,0]/pos_a[0]): 21.952768
#  (pos_other[g,1]/pos_a[1]): 0.785959
# dif [ 0.98890598 -0.01594782]
# acc_temp [-0.75912612  0.01224222]
# g 1
#  (pos_other[g,0]/pos_a[0]): -20.388102
#  (pos_other[g,1]/pos_a[1]): 0.785874
# dif [-1.00945238 -0.0159542 ]
# acc_temp [1.32497008 0.0209409 ]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56584396 0.03318312]
# a_full [0.56584396 0.03318312]
# acc_array [[ 0.          0.        ]
#  [ 1.66366075 -0.02213731]
#  [-0.94280208 -0.01149471]
#  [ 0.56584396  0.03318312]]
# vel-new_vel [[-0.0056575  -0.00033179]
#  [-0.00565415 -0.00033178]
#  [-0.00565689 -0.00033181]]
# pos [-1.03610289 -0.05856053]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.928726
#  (pos_other[g,1]/pos_a[1]): 0.999891
# dif [-1.99835836e+00 -6.38835623e-06]
# acc_temp [2.90893380e-01 9.29928572e-07]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.045552
#  (pos_other[g,1]/pos_a[1]): 1.27233
# dif [-0.98890598  0.01594782]
# acc_temp [ 1.37276737 -0.02213824]
# sum acc [ 1.66366075 -0.02213731]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.076744
#  (pos_other[g,1]/pos_a[1]): 1.000109
# dif [1.99835836e+00 6.38835623e-06]
# acc_temp [-2.15554145e-01 -6.89083945e-07]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.049048
#  (pos_other[g,1]/pos_a[1]): 1.272469
# dif [1.00945238 0.0159542 ]
# acc_temp [-0.72724793 -0.01149402]
# sum acc [-0.94280208 -0.01149471]
# g 0
#  (pos_other[g,0]/pos_a[0]): 21.952768
#  (pos_other[g,1]/pos_a[1]): 0.785959
# dif [ 0.98890598 -0.01594782]
# acc_temp [-0.75912612  0.01224222]
# g 1
#  (pos_other[g,0]/pos_a[0]): -20.388102
#  (pos_other[g,1]/pos_a[1]): 0.785874
# dif [-1.00945238 -0.0159542 ]
# acc_temp [1.32497008 0.0209409 ]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56584396 0.03318312]
# a_half [0.56584396 0.03318312]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.916623
#  (pos_other[g,1]/pos_a[1]): 0.999892
# dif [-1.99809771e+00 -7.45261706e-06]
# acc_temp [2.90974970e-01 1.08529478e-06]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.051523
#  (pos_other[g,1]/pos_a[1]): 1.23039
# dif [-0.98879619  0.01594228]
# acc_temp [ 1.37311844 -0.02213868]
# sum acc [ 1.66409341 -0.0221376 ]
# a_full [ 1.66409341 -0.0221376 ]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.090961
#  (pos_other[g,1]/pos_a[1]): 1.000108
# dif [1.99809771e+00 7.45261706e-06]
# acc_temp [-2.15606166e-01 -8.04179988e-07]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.05621
#  (pos_other[g,1]/pos_a[1]): 1.230523
# dif [1.00930152 0.01594974]
# acc_temp [-0.72743366 -0.01149545]
# sum acc [-0.94303983 -0.01149625]
# a_full [-0.94303983 -0.01149625]
# g 0
#  (pos_other[g,0]/pos_a[0]): 19.408799
#  (pos_other[g,1]/pos_a[1]): 0.81275
# dif [ 0.98879619 -0.01594228]
# acc_temp [-0.75926922  0.01224164]
# g 1
#  (pos_other[g,0]/pos_a[0]): -17.790554
#  (pos_other[g,1]/pos_a[1]): 0.812663
# dif [-1.00930152 -0.01594974]
# acc_temp [1.32542418 0.02094534]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56615496 0.03318698]
# a_full [0.56615496 0.03318698]
# acc_array [[ 0.          0.        ]
#  [ 1.66409341 -0.0221376 ]
#  [-0.94303983 -0.01149625]
#  [ 0.56615496  0.03318698]]
# vel-new_vel [[-0.0056606  -0.00033183]
#  [-0.00565725 -0.00033182]
#  [-0.00565999 -0.00033185]]
# pos [-1.04250943 -0.06919684]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.916623
#  (pos_other[g,1]/pos_a[1]): 0.999892
# dif [-1.99809771e+00 -7.45261706e-06]
# acc_temp [2.90974970e-01 1.08529478e-06]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.051523
#  (pos_other[g,1]/pos_a[1]): 1.23039
# dif [-0.98879619  0.01594228]
# acc_temp [ 1.37311844 -0.02213868]
# sum acc [ 1.66409341 -0.0221376 ]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.090961
#  (pos_other[g,1]/pos_a[1]): 1.000108
# dif [1.99809771e+00 7.45261706e-06]
# acc_temp [-2.15606166e-01 -8.04179988e-07]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.05621
#  (pos_other[g,1]/pos_a[1]): 1.230523
# dif [1.00930152 0.01594974]
# acc_temp [-0.72743366 -0.01149545]
# sum acc [-0.94303983 -0.01149625]
# g 0
#  (pos_other[g,0]/pos_a[0]): 19.408799
#  (pos_other[g,1]/pos_a[1]): 0.81275
# dif [ 0.98879619 -0.01594228]
# acc_temp [-0.75926922  0.01224164]
# g 1
#  (pos_other[g,0]/pos_a[0]): -17.790554
#  (pos_other[g,1]/pos_a[1]): 0.812663
# dif [-1.00930152 -0.01594974]
# acc_temp [1.32542418 0.02094534]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56615496 0.03318698]
# a_half [0.56615496 0.03318698]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.904771
#  (pos_other[g,1]/pos_a[1]): 0.999893
# dif [-1.99783700e+00 -8.51675126e-06]
# acc_temp [2.91056615e-01 1.24077029e-06]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.05737
#  (pos_other[g,1]/pos_a[1]): 1.199634
# dif [-0.9886864   0.01593675]
# acc_temp [ 1.37346968 -0.02213912]
# sum acc [ 1.6645263  -0.02213788]
# a_full [ 1.6645263  -0.02213788]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.105252
#  (pos_other[g,1]/pos_a[1]): 1.000107
# dif [1.99783700e+00 8.51675126e-06]
# acc_temp [-2.15658220e-01 -9.19347985e-07]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.063408
#  (pos_other[g,1]/pos_a[1]): 1.199762
# dif [1.0091506  0.01594527]
# acc_temp [-0.72761952 -0.01149689]
# sum acc [-0.94327774 -0.0114978 ]
# a_full [-0.94327774 -0.0114978 ]
# g 0
#  (pos_other[g,0]/pos_a[0]): 17.430745
#  (pos_other[g,1]/pos_a[1]): 0.833588
# dif [ 0.9886864  -0.01593675]
# acc_temp [-0.75941238  0.01224106]
# g 1
#  (pos_other[g,0]/pos_a[0]): -15.770835
#  (pos_other[g,1]/pos_a[1]): 0.833499
# dif [-1.0091506  -0.01594527]
# acc_temp [1.32587868 0.02094979]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.5664663  0.03319084]
# a_full [0.5664663  0.03319084]
# acc_array [[ 0.          0.        ]
#  [ 1.6645263  -0.02213788]
#  [-0.94327774 -0.0114978 ]
#  [ 0.5664663   0.03319084]]
# vel-new_vel [[-0.00566371 -0.00033187]
#  [-0.00566036 -0.00033186]
#  [-0.00566311 -0.00033189]]
# pos [-1.04885935 -0.07982984]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.904771
#  (pos_other[g,1]/pos_a[1]): 0.999893
# dif [-1.99783700e+00 -8.51675126e-06]
# acc_temp [2.91056615e-01 1.24077029e-06]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.05737
#  (pos_other[g,1]/pos_a[1]): 1.199634
# dif [-0.9886864   0.01593675]
# acc_temp [ 1.37346968 -0.02213912]
# sum acc [ 1.6645263  -0.02213788]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.105252
#  (pos_other[g,1]/pos_a[1]): 1.000107
# dif [1.99783700e+00 8.51675126e-06]
# acc_temp [-2.15658220e-01 -9.19347985e-07]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.063408
#  (pos_other[g,1]/pos_a[1]): 1.199762
# dif [1.0091506  0.01594527]
# acc_temp [-0.72761952 -0.01149689]
# sum acc [-0.94327774 -0.0114978 ]
# g 0
#  (pos_other[g,0]/pos_a[0]): 17.430745
#  (pos_other[g,1]/pos_a[1]): 0.833588
# dif [ 0.9886864  -0.01593675]
# acc_temp [-0.75941238  0.01224106]
# g 1
#  (pos_other[g,0]/pos_a[0]): -15.770835
#  (pos_other[g,1]/pos_a[1]): 0.833499
# dif [-1.0091506  -0.01594527]
# acc_temp [1.32587868 0.02094979]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.5664663  0.03319084]
# a_half [0.5664663  0.03319084]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.893163
#  (pos_other[g,1]/pos_a[1]): 0.999894
# dif [-1.99757622e+00 -9.58075855e-06]
# acc_temp [2.91138315e-01 1.39635518e-06]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.063096
#  (pos_other[g,1]/pos_a[1]): 1.176114
# dif [-0.98857659  0.01593122]
# acc_temp [ 1.3738211  -0.02213955]
# sum acc [ 1.66495941 -0.02213816]
# a_full [ 1.66495941 -0.02213816]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.119616
#  (pos_other[g,1]/pos_a[1]): 1.000106
# dif [1.99757622e+00 9.58075855e-06]
# acc_temp [-2.15710307e-01 -1.03458799e-06]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.070643
#  (pos_other[g,1]/pos_a[1]): 1.176239
# dif [1.00899962 0.0159408 ]
# acc_temp [-0.72780553 -0.01149832]
# sum acc [-0.94351583 -0.01149936]
# a_full [-0.94351583 -0.01149936]
# g 0
#  (pos_other[g,0]/pos_a[0]): 15.84884
#  (pos_other[g,1]/pos_a[1]): 0.850257
# dif [ 0.98857659 -0.01593122]
# acc_temp [-0.75955559  0.01224047]
# g 1
#  (pos_other[g,0]/pos_a[0]): -14.155603
#  (pos_other[g,1]/pos_a[1]): 0.850167
# dif [-1.00899962 -0.0159408 ]
# acc_temp [1.32633357 0.02095424]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56677798 0.03319471]
# a_full [0.56677798 0.03319471]
# acc_array [[ 0.          0.        ]
#  [ 1.66495941 -0.02213816]
#  [-0.94351583 -0.01149936]
#  [ 0.56677798  0.03319471]]
# vel-new_vel [[-0.00566683 -0.00033191]
#  [-0.00566347 -0.0003319 ]
#  [-0.00566622 -0.00033193]]
# pos [-1.05515261 -0.09045951]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.893163
#  (pos_other[g,1]/pos_a[1]): 0.999894
# dif [-1.99757622e+00 -9.58075855e-06]
# acc_temp [2.91138315e-01 1.39635518e-06]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.063096
#  (pos_other[g,1]/pos_a[1]): 1.176114
# dif [-0.98857659  0.01593122]
# acc_temp [ 1.3738211  -0.02213955]
# sum acc [ 1.66495941 -0.02213816]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.119616
#  (pos_other[g,1]/pos_a[1]): 1.000106
# dif [1.99757622e+00 9.58075855e-06]
# acc_temp [-2.15710307e-01 -1.03458799e-06]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.070643
#  (pos_other[g,1]/pos_a[1]): 1.176239
# dif [1.00899962 0.0159408 ]
# acc_temp [-0.72780553 -0.01149832]
# sum acc [-0.94351583 -0.01149936]
# g 0
#  (pos_other[g,0]/pos_a[0]): 15.84884
#  (pos_other[g,1]/pos_a[1]): 0.850257
# dif [ 0.98857659 -0.01593122]
# acc_temp [-0.75955559  0.01224047]
# g 1
#  (pos_other[g,0]/pos_a[0]): -14.155603
#  (pos_other[g,1]/pos_a[1]): 0.850167
# dif [-1.00899962 -0.0159408 ]
# acc_temp [1.32633357 0.02095424]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56677798 0.03319471]
# a_half [0.56677798 0.03319471]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.881794
#  (pos_other[g,1]/pos_a[1]): 0.999895
# dif [-1.99731537e+00 -1.06446387e-05]
# acc_temp [2.91220071e-01 1.55204955e-06]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.068705
#  (pos_other[g,1]/pos_a[1]): 1.157546
# dif [-0.98846678  0.01592569]
# acc_temp [ 1.37417269 -0.02213999]
# sum acc [ 1.66539276 -0.02213844]
# a_full [ 1.66539276 -0.02213844]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.134052
#  (pos_other[g,1]/pos_a[1]): 1.000105
# dif [1.99731537e+00 1.06446387e-05]
# acc_temp [-2.15762425e-01 -1.14990005e-06]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.077915
#  (pos_other[g,1]/pos_a[1]): 1.157668
# dif [1.0088486  0.01593633]
# acc_temp [-0.72799167 -0.01149976]
# sum acc [-0.94375409 -0.01150091]
# a_full [-0.94375409 -0.01150091]
# g 0
#  (pos_other[g,0]/pos_a[0]): 14.55505
#  (pos_other[g,1]/pos_a[1]): 0.863896
# dif [ 0.98846678 -0.01592569]
# acc_temp [-0.75969886  0.01223989]
# g 1
#  (pos_other[g,0]/pos_a[0]): -12.83455
#  (pos_other[g,1]/pos_a[1]): 0.863806
# dif [-1.0088486  -0.01593633]
# acc_temp [1.32678887 0.02095869]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56709001 0.03319858]
# a_full [0.56709001 0.03319858]
# acc_array [[ 0.          0.        ]
#  [ 1.66539276 -0.02213844]
#  [-0.94375409 -0.01150091]
#  [ 0.56709001  0.03319858]]
# vel-new_vel [[-0.00566995 -0.00033195]
#  [-0.00566659 -0.00033194]
#  [-0.00566934 -0.00033197]]
# pos [-1.06138918 -0.10108587]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.881794
#  (pos_other[g,1]/pos_a[1]): 0.999895
# dif [-1.99731537e+00 -1.06446387e-05]
# acc_temp [2.91220071e-01 1.55204955e-06]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.068705
#  (pos_other[g,1]/pos_a[1]): 1.157546
# dif [-0.98846678  0.01592569]
# acc_temp [ 1.37417269 -0.02213999]
# sum acc [ 1.66539276 -0.02213844]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.134052
#  (pos_other[g,1]/pos_a[1]): 1.000105
# dif [1.99731537e+00 1.06446387e-05]
# acc_temp [-2.15762425e-01 -1.14990005e-06]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.077915
#  (pos_other[g,1]/pos_a[1]): 1.157668
# dif [1.0088486  0.01593633]
# acc_temp [-0.72799167 -0.01149976]
# sum acc [-0.94375409 -0.01150091]
# g 0
#  (pos_other[g,0]/pos_a[0]): 14.55505
#  (pos_other[g,1]/pos_a[1]): 0.863896
# dif [ 0.98846678 -0.01592569]
# acc_temp [-0.75969886  0.01223989]
# g 1
#  (pos_other[g,0]/pos_a[0]): -12.83455
#  (pos_other[g,1]/pos_a[1]): 0.863806
# dif [-1.0088486  -0.01593633]
# acc_temp [1.32678887 0.02095869]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56709001 0.03319858]
# a_half [0.56709001 0.03319858]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.870656
#  (pos_other[g,1]/pos_a[1]): 0.999895
# dif [-1.99705446e+00 -1.17083913e-05]
# acc_temp [2.91301882e-01 1.70785349e-06]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.074199
#  (pos_other[g,1]/pos_a[1]): 1.142515
# dif [-0.98835695  0.01592015]
# acc_temp [ 1.37452445 -0.02214042]
# sum acc [ 1.66582633 -0.02213871]
# a_full [ 1.66582633 -0.02213871]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.148559
#  (pos_other[g,1]/pos_a[1]): 1.000105
# dif [1.99705446e+00 1.17083913e-05]
# acc_temp [-2.15814576e-01 -1.26528423e-06]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.085221
#  (pos_other[g,1]/pos_a[1]): 1.142634
# dif [1.00869751 0.01593186]
# acc_temp [-0.72817794 -0.0115012 ]
# sum acc [-0.94399252 -0.01150246]
# a_full [-0.94399252 -0.01150246]
# g 0
#  (pos_other[g,0]/pos_a[0]): 13.477352
#  (pos_other[g,1]/pos_a[1]): 0.875262
# dif [ 0.98835695 -0.01592015]
# acc_temp [-0.75984218  0.01223931]
# g 1
#  (pos_other[g,0]/pos_a[0]): -11.734138
#  (pos_other[g,1]/pos_a[1]): 0.875171
# dif [-1.00869751 -0.01593186]
# acc_temp [1.32724456 0.02096315]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56740238 0.03320245]
# a_full [0.56740238 0.03320245]
# acc_array [[ 0.          0.        ]
#  [ 1.66582633 -0.02213871]
#  [-0.94399252 -0.01150246]
#  [ 0.56740238  0.03320245]]
# vel-new_vel [[-0.00567307 -0.00033198]
#  [-0.00566971 -0.00033198]
#  [-0.00567246 -0.00033201]]
# pos [-1.06756902 -0.1117089 ]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.870656
#  (pos_other[g,1]/pos_a[1]): 0.999895
# dif [-1.99705446e+00 -1.17083913e-05]
# acc_temp [2.91301882e-01 1.70785349e-06]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.074199
#  (pos_other[g,1]/pos_a[1]): 1.142515
# dif [-0.98835695  0.01592015]
# acc_temp [ 1.37452445 -0.02214042]
# sum acc [ 1.66582633 -0.02213871]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.148559
#  (pos_other[g,1]/pos_a[1]): 1.000105
# dif [1.99705446e+00 1.17083913e-05]
# acc_temp [-2.15814576e-01 -1.26528423e-06]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.085221
#  (pos_other[g,1]/pos_a[1]): 1.142634
# dif [1.00869751 0.01593186]
# acc_temp [-0.72817794 -0.0115012 ]
# sum acc [-0.94399252 -0.01150246]
# g 0
#  (pos_other[g,0]/pos_a[0]): 13.477352
#  (pos_other[g,1]/pos_a[1]): 0.875262
# dif [ 0.98835695 -0.01592015]
# acc_temp [-0.75984218  0.01223931]
# g 1
#  (pos_other[g,0]/pos_a[0]): -11.734138
#  (pos_other[g,1]/pos_a[1]): 0.875171
# dif [-1.00869751 -0.01593186]
# acc_temp [1.32724456 0.02096315]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56740238 0.03320245]
# a_half [0.56740238 0.03320245]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.859745
#  (pos_other[g,1]/pos_a[1]): 0.999896
# dif [-1.99679348e+00 -1.27720162e-05]
# acc_temp [2.91383749e-01 1.86376709e-06]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.079581
#  (pos_other[g,1]/pos_a[1]): 1.130097
# dif [-0.9882471   0.01591462]
# acc_temp [ 1.37487638 -0.02214085]
# sum acc [ 1.66626013 -0.02213899]
# a_full [ 1.66626013 -0.02213899]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.163136
#  (pos_other[g,1]/pos_a[1]): 1.000104
# dif [1.99679348e+00 1.27720162e-05]
# acc_temp [-2.15866759e-01 -1.38074056e-06]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.092563
#  (pos_other[g,1]/pos_a[1]): 1.130215
# dif [1.00854637 0.01592739]
# acc_temp [-0.72836436 -0.01150264]
# sum acc [-0.94423112 -0.01150402]
# a_full [-0.94423112 -0.01150402]
# g 0
#  (pos_other[g,0]/pos_a[0]): 12.565884
#  (pos_other[g,1]/pos_a[1]): 0.88488
# dif [ 0.9882471  -0.01591462]
# acc_temp [-0.75998556  0.01223872]
# g 1
#  (pos_other[g,0]/pos_a[0]): -10.803455
#  (pos_other[g,1]/pos_a[1]): 0.884787
# dif [-1.00854637 -0.01592739]
# acc_temp [1.32770066 0.02096761]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56771509 0.03320633]
# a_full [0.56771509 0.03320633]
# acc_array [[ 0.          0.        ]
#  [ 1.66626013 -0.02213899]
#  [-0.94423112 -0.01150402]
#  [ 0.56771509  0.03320633]]
# vel-new_vel [[-0.00567619 -0.00033202]
#  [-0.00567283 -0.00033202]
#  [-0.00567559 -0.00033204]]
# pos [-1.07369212 -0.12232862]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.859745
#  (pos_other[g,1]/pos_a[1]): 0.999896
# dif [-1.99679348e+00 -1.27720162e-05]
# acc_temp [2.91383749e-01 1.86376709e-06]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.079581
#  (pos_other[g,1]/pos_a[1]): 1.130097
# dif [-0.9882471   0.01591462]
# acc_temp [ 1.37487638 -0.02214085]
# sum acc [ 1.66626013 -0.02213899]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.163136
#  (pos_other[g,1]/pos_a[1]): 1.000104
# dif [1.99679348e+00 1.27720162e-05]
# acc_temp [-2.15866759e-01 -1.38074056e-06]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.092563
#  (pos_other[g,1]/pos_a[1]): 1.130215
# dif [1.00854637 0.01592739]
# acc_temp [-0.72836436 -0.01150264]
# sum acc [-0.94423112 -0.01150402]
# g 0
#  (pos_other[g,0]/pos_a[0]): 12.565884
#  (pos_other[g,1]/pos_a[1]): 0.88488
# dif [ 0.9882471  -0.01591462]
# acc_temp [-0.75998556  0.01223872]
# g 1
#  (pos_other[g,0]/pos_a[0]): -10.803455
#  (pos_other[g,1]/pos_a[1]): 0.884787
# dif [-1.00854637 -0.01592739]
# acc_temp [1.32770066 0.02096761]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56771509 0.03320633]
# a_half [0.56771509 0.03320633]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.849055
#  (pos_other[g,1]/pos_a[1]): 0.999896
# dif [-1.99653243e+00 -1.38355132e-05]
# acc_temp [2.91465671e-01 2.01979045e-06]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.084853
#  (pos_other[g,1]/pos_a[1]): 1.119667
# dif [-0.98813725  0.01590908]
# acc_temp [ 1.37522849 -0.02214128]
# sum acc [ 1.66669416 -0.02213926]
# a_full [ 1.66669416 -0.02213926]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.17778
#  (pos_other[g,1]/pos_a[1]): 1.000104
# dif [1.99653243e+00 1.38355132e-05]
# acc_temp [-2.15918974e-01 -1.49626912e-06]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.099939
#  (pos_other[g,1]/pos_a[1]): 1.119783
# dif [1.00839518 0.01592292]
# acc_temp [-0.72855092 -0.01150408]
# sum acc [-0.94446989 -0.01150557]
# a_full [-0.94446989 -0.01150557]
# g 0
#  (pos_other[g,0]/pos_a[0]): 11.785031
#  (pos_other[g,1]/pos_a[1]): 0.893123
# dif [ 0.98813725 -0.01590908]
# acc_temp [-0.760129    0.01223813]
# g 1
#  (pos_other[g,0]/pos_a[0]): -10.006136
#  (pos_other[g,1]/pos_a[1]): 0.89303
# dif [-1.00839518 -0.01592292]
# acc_temp [1.32815715 0.02097207]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56802815 0.03321021]
# a_full [0.56802815 0.03321021]
# acc_array [[ 0.          0.        ]
#  [ 1.66669416 -0.02213926]
#  [-0.94446989 -0.01150557]
#  [ 0.56802815  0.03321021]]
# vel-new_vel [[-0.00567932 -0.00033206]
#  [-0.00567596 -0.00033206]
#  [-0.00567872 -0.00033208]]
# pos [-1.07975843 -0.13294502]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.849055
#  (pos_other[g,1]/pos_a[1]): 0.999896
# dif [-1.99653243e+00 -1.38355132e-05]
# acc_temp [2.91465671e-01 2.01979045e-06]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.084853
#  (pos_other[g,1]/pos_a[1]): 1.119667
# dif [-0.98813725  0.01590908]
# acc_temp [ 1.37522849 -0.02214128]
# sum acc [ 1.66669416 -0.02213926]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.17778
#  (pos_other[g,1]/pos_a[1]): 1.000104
# dif [1.99653243e+00 1.38355132e-05]
# acc_temp [-2.15918974e-01 -1.49626912e-06]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.099939
#  (pos_other[g,1]/pos_a[1]): 1.119783
# dif [1.00839518 0.01592292]
# acc_temp [-0.72855092 -0.01150408]
# sum acc [-0.94446989 -0.01150557]
# g 0
#  (pos_other[g,0]/pos_a[0]): 11.785031
#  (pos_other[g,1]/pos_a[1]): 0.893123
# dif [ 0.98813725 -0.01590908]
# acc_temp [-0.760129    0.01223813]
# g 1
#  (pos_other[g,0]/pos_a[0]): -10.006136
#  (pos_other[g,1]/pos_a[1]): 0.89303
# dif [-1.00839518 -0.01592292]
# acc_temp [1.32815715 0.02097207]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56802815 0.03321021]
# a_half [0.56802815 0.03321021]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.83858
#  (pos_other[g,1]/pos_a[1]): 0.999896
# dif [-1.99627131e+00 -1.48988818e-05]
# acc_temp [2.91547649e-01 2.17592365e-06]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.09002
#  (pos_other[g,1]/pos_a[1]): 1.110781
# dif [-0.98802738  0.01590355]
# acc_temp [ 1.37558077 -0.02214171]
# sum acc [ 1.66712841 -0.02213953]
# a_full [ 1.66712841 -0.02213953]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.192492
#  (pos_other[g,1]/pos_a[1]): 1.000104
# dif [1.99627131e+00 1.48988818e-05]
# acc_temp [-2.15971222e-01 -1.61186994e-06]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.107348
#  (pos_other[g,1]/pos_a[1]): 1.110897
# dif [1.00824393 0.01591845]
# acc_temp [-0.72873761 -0.01150552]
# sum acc [-0.94470884 -0.01150713]
# a_full [-0.94470884 -0.01150713]
# g 0
#  (pos_other[g,0]/pos_a[0]): 11.108675
#  (pos_other[g,1]/pos_a[1]): 0.900267
# dif [ 0.98802738 -0.01590355]
# acc_temp [-0.76027249  0.01223755]
# g 1
#  (pos_other[g,0]/pos_a[0]): -9.315514
#  (pos_other[g,1]/pos_a[1]): 0.900174
# dif [-1.00824393 -0.01591845]
# acc_temp [1.32861404 0.02097654]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56834155 0.03321409]
# a_full [0.56834155 0.03321409]
# acc_array [[ 0.          0.        ]
#  [ 1.66712841 -0.02213953]
#  [-0.94470884 -0.01150713]
#  [ 0.56834155  0.03321409]]
# vel-new_vel [[-0.00568245 -0.0003321 ]
#  [-0.00567909 -0.00033209]
#  [-0.00568185 -0.00033212]]
# pos [-1.08576793 -0.14355809]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.83858
#  (pos_other[g,1]/pos_a[1]): 0.999896
# dif [-1.99627131e+00 -1.48988818e-05]
# acc_temp [2.91547649e-01 2.17592365e-06]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.09002
#  (pos_other[g,1]/pos_a[1]): 1.110781
# dif [-0.98802738  0.01590355]
# acc_temp [ 1.37558077 -0.02214171]
# sum acc [ 1.66712841 -0.02213953]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.192492
#  (pos_other[g,1]/pos_a[1]): 1.000104
# dif [1.99627131e+00 1.48988818e-05]
# acc_temp [-2.15971222e-01 -1.61186994e-06]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.107348
#  (pos_other[g,1]/pos_a[1]): 1.110897
# dif [1.00824393 0.01591845]
# acc_temp [-0.72873761 -0.01150552]
# sum acc [-0.94470884 -0.01150713]
# g 0
#  (pos_other[g,0]/pos_a[0]): 11.108675
#  (pos_other[g,1]/pos_a[1]): 0.900267
# dif [ 0.98802738 -0.01590355]
# acc_temp [-0.76027249  0.01223755]
# g 1
#  (pos_other[g,0]/pos_a[0]): -9.315514
#  (pos_other[g,1]/pos_a[1]): 0.900174
# dif [-1.00824393 -0.01591845]
# acc_temp [1.32861404 0.02097654]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56834155 0.03321409]
# a_half [0.56834155 0.03321409]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.828316
#  (pos_other[g,1]/pos_a[1]): 0.999896
# dif [-1.99601013e+00 -1.59621219e-05]
# acc_temp [2.91629682e-01 2.33216679e-06]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.095082
#  (pos_other[g,1]/pos_a[1]): 1.103121
# dif [-0.9879175   0.01589801]
# acc_temp [ 1.37593322 -0.02214214]
# sum acc [ 1.6675629 -0.0221398]
# a_full [ 1.6675629 -0.0221398]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.207269
#  (pos_other[g,1]/pos_a[1]): 1.000104
# dif [1.99601013e+00 1.59621219e-05]
# acc_temp [-2.16023502e-01 -1.72754307e-06]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.11479
#  (pos_other[g,1]/pos_a[1]): 1.103236
# dif [1.00809262 0.01591397]
# acc_temp [-0.72892445 -0.01150696]
# sum acc [-0.94494795 -0.01150869]
# a_full [-0.94494795 -0.01150869]
# g 0
#  (pos_other[g,0]/pos_a[0]): 10.517228
#  (pos_other[g,1]/pos_a[1]): 0.906518
# dif [ 0.9879175  -0.01589801]
# acc_temp [-0.76041604  0.01223696]
# g 1
#  (pos_other[g,0]/pos_a[0]): -8.711588
#  (pos_other[g,1]/pos_a[1]): 0.906425
# dif [-1.00809262 -0.01591397]
# acc_temp [1.32907134 0.02098102]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.5686553  0.03321797]
# a_full [0.5686553  0.03321797]
# acc_array [[ 0.          0.        ]
#  [ 1.6675629  -0.0221398 ]
#  [-0.94494795 -0.01150869]
#  [ 0.5686553   0.03321797]]
# vel-new_vel [[-0.00568559 -0.00033214]
#  [-0.00568222 -0.00033213]
#  [-0.00568498 -0.00033216]]
# pos [-1.09172058 -0.15416785]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.828316
#  (pos_other[g,1]/pos_a[1]): 0.999896
# dif [-1.99601013e+00 -1.59621219e-05]
# acc_temp [2.91629682e-01 2.33216679e-06]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.095082
#  (pos_other[g,1]/pos_a[1]): 1.103121
# dif [-0.9879175   0.01589801]
# acc_temp [ 1.37593322 -0.02214214]
# sum acc [ 1.6675629 -0.0221398]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.207269
#  (pos_other[g,1]/pos_a[1]): 1.000104
# dif [1.99601013e+00 1.59621219e-05]
# acc_temp [-2.16023502e-01 -1.72754307e-06]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.11479
#  (pos_other[g,1]/pos_a[1]): 1.103236
# dif [1.00809262 0.01591397]
# acc_temp [-0.72892445 -0.01150696]
# sum acc [-0.94494795 -0.01150869]
# g 0
#  (pos_other[g,0]/pos_a[0]): 10.517228
#  (pos_other[g,1]/pos_a[1]): 0.906518
# dif [ 0.9879175  -0.01589801]
# acc_temp [-0.76041604  0.01223696]
# g 1
#  (pos_other[g,0]/pos_a[0]): -8.711588
#  (pos_other[g,1]/pos_a[1]): 0.906425
# dif [-1.00809262 -0.01591397]
# acc_temp [1.32907134 0.02098102]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.5686553  0.03321797]
# a_half [0.5686553  0.03321797]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.818257
#  (pos_other[g,1]/pos_a[1]): 0.999897
# dif [-1.99574887e+00 -1.70252331e-05]
# acc_temp [2.91711772e-01 2.48851997e-06]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.100043
#  (pos_other[g,1]/pos_a[1]): 1.09645
# dif [-0.98780761  0.01589248]
# acc_temp [ 1.37628585 -0.02214256]
# sum acc [ 1.66799762 -0.02214007]
# a_full [ 1.66799762 -0.02214007]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.22211
#  (pos_other[g,1]/pos_a[1]): 1.000103
# dif [1.99574887e+00 1.70252331e-05]
# acc_temp [-2.16075815e-01 -1.84328858e-06]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.122263
#  (pos_other[g,1]/pos_a[1]): 1.096563
# dif [1.00794126 0.0159095 ]
# acc_temp [-0.72911142 -0.01150841]
# sum acc [-0.94518724 -0.01151025]
# a_full [-0.94518724 -0.01151025]
# g 0
#  (pos_other[g,0]/pos_a[0]): 9.995711
#  (pos_other[g,1]/pos_a[1]): 0.912034
# dif [ 0.98780761 -0.01589248]
# acc_temp [-0.76055964  0.01223637]
# g 1
#  (pos_other[g,0]/pos_a[0]): -8.179063
#  (pos_other[g,1]/pos_a[1]): 0.91194
# dif [-1.00794126 -0.0159095 ]
# acc_temp [1.32952904 0.02098549]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.56896939 0.03322186]
# a_full [0.56896939 0.03322186]
# acc_array [[ 0.          0.        ]
#  [ 1.66799762 -0.02214007]
#  [-0.94518724 -0.01151025]
#  [ 0.56896939  0.03322186]]
# vel-new_vel [[-0.00568873 -0.00033218]
#  [-0.00568536 -0.00033217]
#  [-0.00568812 -0.0003322 ]]
# pos [-1.09761635 -0.16477428]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): -0.818257
#  (pos_other[g,1]/pos_a[1]): 0.999897
# dif [-1.99574887e+00 -1.70252331e-05]
# acc_temp [2.91711772e-01 2.48851997e-06]
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.100043
#  (pos_other[g,1]/pos_a[1]): 1.09645
# dif [-0.98780761  0.01589248]
# acc_temp [ 1.37628585 -0.02214256]
# sum acc [ 1.66799762 -0.02214007]
# g 0
#  (pos_other[g,0]/pos_a[0]): -1.22211
#  (pos_other[g,1]/pos_a[1]): 1.000103
# dif [1.99574887e+00 1.70252331e-05]
# acc_temp [-2.16075815e-01 -1.84328858e-06]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): -0.122263
#  (pos_other[g,1]/pos_a[1]): 1.096563
# dif [1.00794126 0.0159095 ]
# acc_temp [-0.72911142 -0.01150841]
# sum acc [-0.94518724 -0.01151025]
# g 0
#  (pos_other[g,0]/pos_a[0]): 9.995711
#  (pos_other[g,1]/pos_a[1]): 0.912034
# dif [ 0.98780761 -0.01589248]
# acc_temp [-0.76055964  0.01223637]
# g 1
#  (pos_other[g,0]/pos_a[0]): -8.179063
#  (pos_other[g,1]/pos_a[1]): 0.91194
# dif [-1.00794126 -0.0159095 ]
# acc_temp [1.32952904 0.02098549]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
# ...
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.817886
#  (pos_other[g,1]/pos_a[1]): 1.002833
# dif [0.92829026 0.0137044 ]
# acc_temp [-0.83833904 -0.01237644]
# sum acc [-1.08375387 -0.01244273]
# g 0
#  (pos_other[g,0]/pos_a[0]): 0.775882
#  (pos_other[g,1]/pos_a[1]): 0.997279
# dif [ 0.93435016 -0.01320132]
# acc_temp [-0.83547908  0.01180438]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.222665
#  (pos_other[g,1]/pos_a[1]): 0.997175
# dif [-0.92829026 -0.0137044 ]
# acc_temp [1.60732285 0.02372899]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.77184377 0.03553337]
# a_half [0.77184377 0.03553337]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.571214
#  (pos_other[g,1]/pos_a[1]): 0.999896
# dif [-1.86234167e+00 -5.04041251e-04]
# acc_temp [3.38622612e-01 9.16479331e-05]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.286547
#  (pos_other[g,1]/pos_a[1]): 1.002723
# dif [-0.93423697  0.01319556]
# acc_temp [ 1.56568381 -0.02211438]
# sum acc [ 1.90430643 -0.02202273]
# a_full [ 1.90430643 -0.02202273]
# g 0
#  (pos_other[g,0]/pos_a[0]): 0.636451
#  (pos_other[g,1]/pos_a[1]): 1.000104
# dif [1.86234167e+00 5.04041251e-04]
# acc_temp [-2.45487233e-01 -6.64409190e-05]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.818824
#  (pos_other[g,1]/pos_a[1]): 1.002827
# dif [0.9281047 0.0136996]
# acc_temp [-0.83862118 -0.01237875]
# sum acc [-1.08410842 -0.01244519]
# a_full [-1.08410842 -0.01244519]
# g 0
#  (pos_other[g,0]/pos_a[0]): 0.777274
#  (pos_other[g,1]/pos_a[1]): 0.997285
# dif [ 0.93423697 -0.01319556]
# acc_temp [-0.8356491   0.01180306]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.221264
#  (pos_other[g,1]/pos_a[1]): 0.997181
# dif [-0.9281047 -0.0136996]
# acc_temp [1.60806759 0.02373642]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.77241849 0.03553948]
# a_full [0.77241849 0.03553948]
# acc_array [[ 0.          0.        ]
#  [ 1.90430643 -0.02202273]
#  [-1.08410842 -0.01244519]
#  [ 0.77241849  0.03553948]]
# vel-new_vel [[-0.00772123 -0.00035534]
#  [-0.00771666 -0.00035532]
#  [-0.00772131 -0.00035536]]
# pos [ 3.26032305 -4.84651664]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.571214
#  (pos_other[g,1]/pos_a[1]): 0.999896
# dif [-1.86234167e+00 -5.04041251e-04]
# acc_temp [3.38622612e-01 9.16479331e-05]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.286547
#  (pos_other[g,1]/pos_a[1]): 1.002723
# dif [-0.93423697  0.01319556]
# acc_temp [ 1.56568381 -0.02211438]
# sum acc [ 1.90430643 -0.02202273]
# g 0
#  (pos_other[g,0]/pos_a[0]): 0.636451
#  (pos_other[g,1]/pos_a[1]): 1.000104
# dif [1.86234167e+00 5.04041251e-04]
# acc_temp [-2.45487233e-01 -6.64409190e-05]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.818824
#  (pos_other[g,1]/pos_a[1]): 1.002827
# dif [0.9281047 0.0136996]
# acc_temp [-0.83862118 -0.01237875]
# sum acc [-1.08410842 -0.01244519]
# g 0
#  (pos_other[g,0]/pos_a[0]): 0.777274
#  (pos_other[g,1]/pos_a[1]): 0.997285
# dif [ 0.93423697 -0.01319556]
# acc_temp [-0.8356491   0.01180306]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.221264
#  (pos_other[g,1]/pos_a[1]): 0.997181
# dif [-0.9281047 -0.0136996]
# acc_temp [1.60806759 0.02373642]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.77241849 0.03553948]
# a_half [0.77241849 0.03553948]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.566648
#  (pos_other[g,1]/pos_a[1]): 0.999896
# dif [-1.86204283e+00 -5.04999005e-04]
# acc_temp [3.38740050e-01 9.18686648e-05]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.284268
#  (pos_other[g,1]/pos_a[1]): 1.002716
# dif [-0.93412378  0.0131898 ]
# acc_temp [ 1.5661243  -0.02211363]
# sum acc [ 1.90486435 -0.02202177]
# a_full [ 1.90486435 -0.02202177]
# g 0
#  (pos_other[g,0]/pos_a[0]): 0.638306
#  (pos_other[g,1]/pos_a[1]): 1.000104
# dif [1.86204283e+00 5.04999005e-04]
# acc_temp [-2.45559700e-01 -6.65975036e-05]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.819755
#  (pos_other[g,1]/pos_a[1]): 1.002821
# dif [0.92791905 0.0136948 ]
# acc_temp [-0.8389036  -0.01238106]
# sum acc [-1.0844633  -0.01244765]
# a_full [-1.0844633  -0.01244765]
# g 0
#  (pos_other[g,0]/pos_a[0]): 0.778654
#  (pos_other[g,1]/pos_a[1]): 0.997291
# dif [ 0.93412378 -0.0131898 ]
# acc_temp [-0.83581916  0.01180174]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.219876
#  (pos_other[g,1]/pos_a[1]): 0.997187
# dif [-0.92791905 -0.0136948 ]
# acc_temp [1.60881321 0.02374386]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.77299405 0.0355456 ]
# a_full [0.77299405 0.0355456 ]
# acc_array [[ 0.          0.        ]
#  [ 1.90486435 -0.02202177]
#  [-1.0844633  -0.01244765]
#  [ 0.77299405  0.0355456 ]]
# vel-new_vel [[-0.00772697 -0.0003554 ]
#  [-0.00772241 -0.00035538]
#  [-0.00772706 -0.00035543]]
# pos [ 3.28606845 -4.85548063]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.566648
#  (pos_other[g,1]/pos_a[1]): 0.999896
# dif [-1.86204283e+00 -5.04999005e-04]
# acc_temp [3.38740050e-01 9.18686648e-05]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.284268
#  (pos_other[g,1]/pos_a[1]): 1.002716
# dif [-0.93412378  0.0131898 ]
# acc_temp [ 1.5661243  -0.02211363]
# sum acc [ 1.90486435 -0.02202177]
# g 0
#  (pos_other[g,0]/pos_a[0]): 0.638306
#  (pos_other[g,1]/pos_a[1]): 1.000104
# dif [1.86204283e+00 5.04999005e-04]
# acc_temp [-2.45559700e-01 -6.65975036e-05]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.819755
#  (pos_other[g,1]/pos_a[1]): 1.002821
# dif [0.92791905 0.0136948 ]
# acc_temp [-0.8389036  -0.01238106]
# sum acc [-1.0844633  -0.01244765]
# g 0
#  (pos_other[g,0]/pos_a[0]): 0.778654
#  (pos_other[g,1]/pos_a[1]): 0.997291
# dif [ 0.93412378 -0.0131898 ]
# acc_temp [-0.83581916  0.01180174]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.219876
#  (pos_other[g,1]/pos_a[1]): 0.997187
# dif [-0.92791905 -0.0136948 ]
# acc_temp [1.60881321 0.02374386]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.77299405 0.0355456 ]
# a_half [0.77299405 0.0355456 ]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.562139
#  (pos_other[g,1]/pos_a[1]): 0.999896
# dif [-1.86174390e+00 -5.05956416e-04]
# acc_temp [3.38857586e-01 9.20895565e-05]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.282017
#  (pos_other[g,1]/pos_a[1]): 1.00271
# dif [-0.93401059  0.01318405]
# acc_temp [ 1.56656497 -0.02211288]
# sum acc [ 1.90542256 -0.02202079]
# a_full [ 1.90542256 -0.02202079]
# g 0
#  (pos_other[g,0]/pos_a[0]): 0.640148
#  (pos_other[g,1]/pos_a[1]): 1.000104
# dif [1.86174390e+00 5.05956416e-04]
# acc_temp [-2.45632220e-01 -6.67541858e-05]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.820681
#  (pos_other[g,1]/pos_a[1]): 1.002815
# dif [0.9277333 0.01369  ]
# acc_temp [-0.83918631 -0.01238337]
# sum acc [-1.08481853 -0.01245012]
# a_full [-1.08481853 -0.01245012]
# g 0
#  (pos_other[g,0]/pos_a[0]): 0.780021
#  (pos_other[g,1]/pos_a[1]): 0.997297
# dif [ 0.93401059 -0.01318405]
# acc_temp [-0.83598928  0.01180042]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.218501
#  (pos_other[g,1]/pos_a[1]): 0.997193
# dif [-0.9277333 -0.01369  ]
# acc_temp [1.60955972 0.02375131]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.77357045 0.03555173]
# a_full [0.77357045 0.03555173]
# acc_array [[ 0.          0.        ]
#  [ 1.90542256 -0.02202079]
#  [-1.08481853 -0.01245012]
#  [ 0.77357045  0.03555173]]
# vel-new_vel [[-0.00773273 -0.00035546]
#  [-0.00772816 -0.00035544]
#  [-0.00773282 -0.00035549]]
# pos [ 3.31189115 -4.86444106]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.562139
#  (pos_other[g,1]/pos_a[1]): 0.999896
# dif [-1.86174390e+00 -5.05956416e-04]
# acc_temp [3.38857586e-01 9.20895565e-05]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.282017
#  (pos_other[g,1]/pos_a[1]): 1.00271
# dif [-0.93401059  0.01318405]
# acc_temp [ 1.56656497 -0.02211288]
# sum acc [ 1.90542256 -0.02202079]
# g 0
#  (pos_other[g,0]/pos_a[0]): 0.640148
#  (pos_other[g,1]/pos_a[1]): 1.000104
# dif [1.86174390e+00 5.05956416e-04]
# acc_temp [-2.45632220e-01 -6.67541858e-05]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.820681
#  (pos_other[g,1]/pos_a[1]): 1.002815
# dif [0.9277333 0.01369  ]
# acc_temp [-0.83918631 -0.01238337]
# sum acc [-1.08481853 -0.01245012]
# g 0
#  (pos_other[g,0]/pos_a[0]): 0.780021
#  (pos_other[g,1]/pos_a[1]): 0.997297
# dif [ 0.93401059 -0.01318405]
# acc_temp [-0.83598928  0.01180042]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.218501
#  (pos_other[g,1]/pos_a[1]): 0.997193
# dif [-0.9277333 -0.01369  ]
# acc_temp [1.60955972 0.02375131]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.77357045 0.03555173]
# a_half [0.77357045 0.03555173]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.557688
#  (pos_other[g,1]/pos_a[1]): 0.999896
# dif [-1.86144487e+00 -5.06913483e-04]
# acc_temp [3.38975218e-01 9.23106083e-05]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.279795
#  (pos_other[g,1]/pos_a[1]): 1.002704
# dif [-0.93389741  0.01317829]
# acc_temp [ 1.56700582 -0.02211212]
# sum acc [ 1.90598104 -0.02201981]
# a_full [ 1.90598104 -0.02201981]
# g 0
#  (pos_other[g,0]/pos_a[0]): 0.641977
#  (pos_other[g,1]/pos_a[1]): 1.000104
# dif [1.86144487e+00 5.06913483e-04]
# acc_temp [-2.45704795e-01 -6.69109655e-05]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.821599
#  (pos_other[g,1]/pos_a[1]): 1.002808
# dif [0.92754746 0.0136852 ]
# acc_temp [-0.83946929 -0.01238568]
# sum acc [-1.08517409 -0.01245259]
# a_full [-1.08517409 -0.01245259]
# g 0
#  (pos_other[g,0]/pos_a[0]): 0.781375
#  (pos_other[g,1]/pos_a[1]): 0.997303
# dif [ 0.93389741 -0.01317829]
# acc_temp [-0.83615944  0.0117991 ]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.217138
#  (pos_other[g,1]/pos_a[1]): 0.997199
# dif [-0.92754746 -0.0136852 ]
# acc_temp [1.61030712 0.02375876]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.77414769 0.03555786]
# a_full [0.77414769 0.03555786]
# acc_array [[ 0.          0.        ]
#  [ 1.90598104 -0.02201981]
#  [-1.08517409 -0.01245259]
#  [ 0.77414769  0.03555786]]
# vel-new_vel [[-0.0077385  -0.00035552]
#  [-0.00773393 -0.0003555 ]
#  [-0.00773859 -0.00035555]]
# pos [ 3.3377912  -4.87339795]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.557688
#  (pos_other[g,1]/pos_a[1]): 0.999896
# dif [-1.86144487e+00 -5.06913483e-04]
# acc_temp [3.38975218e-01 9.23106083e-05]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.279795
#  (pos_other[g,1]/pos_a[1]): 1.002704
# dif [-0.93389741  0.01317829]
# acc_temp [ 1.56700582 -0.02211212]
# sum acc [ 1.90598104 -0.02201981]
# g 0
#  (pos_other[g,0]/pos_a[0]): 0.641977
#  (pos_other[g,1]/pos_a[1]): 1.000104
# dif [1.86144487e+00 5.06913483e-04]
# acc_temp [-2.45704795e-01 -6.69109655e-05]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.821599
#  (pos_other[g,1]/pos_a[1]): 1.002808
# dif [0.92754746 0.0136852 ]
# acc_temp [-0.83946929 -0.01238568]
# sum acc [-1.08517409 -0.01245259]
# g 0
#  (pos_other[g,0]/pos_a[0]): 0.781375
#  (pos_other[g,1]/pos_a[1]): 0.997303
# dif [ 0.93389741 -0.01317829]
# acc_temp [-0.83615944  0.0117991 ]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.217138
#  (pos_other[g,1]/pos_a[1]): 0.997199
# dif [-0.92754746 -0.0136852 ]
# acc_temp [1.61030712 0.02375876]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.77414769 0.03555786]
# a_half [0.77414769 0.03555786]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.553292
#  (pos_other[g,1]/pos_a[1]): 0.999896
# dif [-1.86114576e+00 -5.07870205e-04]
# acc_temp [3.39092947e-01 9.25318203e-05]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.277601
#  (pos_other[g,1]/pos_a[1]): 1.002698
# dif [-0.93378423  0.01317253]
# acc_temp [ 1.56744684 -0.02211136]
# sum acc [ 1.90653979 -0.02201883]
# a_full [ 1.90653979 -0.02201883]
# g 0
#  (pos_other[g,0]/pos_a[0]): 0.643794
#  (pos_other[g,1]/pos_a[1]): 1.000104
# dif [1.86114576e+00 5.07870205e-04]
# acc_temp [-2.45777424e-01 -6.70678427e-05]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.822512
#  (pos_other[g,1]/pos_a[1]): 1.002802
# dif [0.92736153 0.0136804 ]
# acc_temp [-0.83975256 -0.012388  ]
# sum acc [-1.08552999 -0.01245507]
# a_full [-1.08552999 -0.01245507]
# g 0
#  (pos_other[g,0]/pos_a[0]): 0.782717
#  (pos_other[g,1]/pos_a[1]): 0.997309
# dif [ 0.93378423 -0.01317253]
# acc_temp [-0.83632965  0.01179778]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.215788
#  (pos_other[g,1]/pos_a[1]): 0.997206
# dif [-0.92736153 -0.0136804 ]
# acc_temp [1.61105542 0.02376623]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.77472577 0.03556401]
# a_full [0.77472577 0.03556401]
# acc_array [[ 0.          0.        ]
#  [ 1.90653979 -0.02201883]
#  [-1.08552999 -0.01245507]
#  [ 0.77472577  0.03556401]]
# vel-new_vel [[-0.00774427 -0.00035558]
#  [-0.0077397  -0.00035557]
#  [-0.00774437 -0.00035561]]
# pos [ 3.36376867 -4.88235127]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.553292
#  (pos_other[g,1]/pos_a[1]): 0.999896
# dif [-1.86114576e+00 -5.07870205e-04]
# acc_temp [3.39092947e-01 9.25318203e-05]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.277601
#  (pos_other[g,1]/pos_a[1]): 1.002698
# dif [-0.93378423  0.01317253]
# acc_temp [ 1.56744684 -0.02211136]
# sum acc [ 1.90653979 -0.02201883]
# g 0
#  (pos_other[g,0]/pos_a[0]): 0.643794
#  (pos_other[g,1]/pos_a[1]): 1.000104
# dif [1.86114576e+00 5.07870205e-04]
# acc_temp [-2.45777424e-01 -6.70678427e-05]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.822512
#  (pos_other[g,1]/pos_a[1]): 1.002802
# dif [0.92736153 0.0136804 ]
# acc_temp [-0.83975256 -0.012388  ]
# sum acc [-1.08552999 -0.01245507]
# g 0
#  (pos_other[g,0]/pos_a[0]): 0.782717
#  (pos_other[g,1]/pos_a[1]): 0.997309
# dif [ 0.93378423 -0.01317253]
# acc_temp [-0.83632965  0.01179778]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.215788
#  (pos_other[g,1]/pos_a[1]): 0.997206
# dif [-0.92736153 -0.0136804 ]
# acc_temp [1.61105542 0.02376623]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.77472577 0.03556401]
# a_half [0.77472577 0.03556401]
# g 0
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.548951
#  (pos_other[g,1]/pos_a[1]): 0.999896
# dif [-1.86084655e+00 -5.08826582e-04]
# acc_temp [3.39210774e-01 9.27531927e-05]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.275434
#  (pos_other[g,1]/pos_a[1]): 1.002692
# dif [-0.93367104  0.01316677]
# acc_temp [ 1.56788805 -0.0221106 ]
# sum acc [ 1.90709882 -0.02201785]
# a_full [ 1.90709882 -0.02201785]
# g 0
#  (pos_other[g,0]/pos_a[0]): 0.645598
#  (pos_other[g,1]/pos_a[1]): 1.000104
# dif [1.86084655e+00 5.08826582e-04]
# acc_temp [-2.45850108e-01 -6.72248177e-05]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# g 2
#  (pos_other[g,0]/pos_a[0]): 0.823418
#  (pos_other[g,1]/pos_a[1]): 1.002796
# dif [0.92717551 0.0136756 ]
# acc_temp [-0.84003612 -0.01239032]
# sum acc [-1.08588622 -0.01245754]
# a_full [-1.08588622 -0.01245754]
# g 0
#  (pos_other[g,0]/pos_a[0]): 0.784047
#  (pos_other[g,1]/pos_a[1]): 0.997315
# dif [ 0.93367104 -0.01316677]
# acc_temp [-0.8364999   0.01179645]
# g 1
#  (pos_other[g,0]/pos_a[0]): 1.21445
#  (pos_other[g,1]/pos_a[1]): 0.997212
# dif [-0.92717551 -0.0136756 ]
# acc_temp [1.61180461 0.0237737 ]
# g 2
#  (pos_other[g,0]/pos_a[0]): 1.0
#  (pos_other[g,1]/pos_a[1]): 1.0
# snap
# sum acc [0.7753047  0.03557015]
# a_full [0.7753047  0.03557015]
# acc_array [[ 0.          0.        ]
#  [ 1.90709882 -0.02201785]
#  [-1.08588622 -0.01245754]
#  [ 0.7753047   0.03557015]]
# vel-new_vel [[-0.00775005 -0.00035564]
#  [-0.00774548 -0.00035563]
#  [-0.00775015 -0.00035567]]

# %%
#ax.set_xlim(-5,5)
#ax.set_ylim(-5,5)
fig

# %%
pos

# %%
vel

# %% [markdown]
# res = pd.read_csv("produced_data_system_0.txt",delim_whitespace=True)
# res
#
# p1_posx = res["p1x"]
# p1_posy = res["p1y"]
#
# fig1 =  plt.figure()
# ax1 = fig1.add_subplot()
# d = np.array([p1_posx,p1_posy])
# ax1.plot(d[0],d[1])
